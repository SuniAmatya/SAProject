# %%
import pandas as pd

# %%
titanic_df = pd.read_csv("titanic.csv", delimiter= ",")
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Inserting and Deleting Rows and Columns
#
#
# Dropping a column
#
# DataFrame.drop(column name, axis)

# %%
titanic_df.drop("PassengerId", axis=1, inplace=True)
#titanic_df.drop(["PassengerId", "Name"], axis= 1, inplace= True)

#titanic_df.drop(columns="PassengerId", inplace=False)
#titanic_df.drop(columns=["PassenerId", "Name"], inplace= True)

# %%
#Dropping a Row

titanic_df.drop(index=[2,4], inplace= False).head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0  A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0   PC 17599  71.2833   C85        C
# 3  female  35.0      1      0     113803  53.1000  C123        S
# 5    male   NaN      0      0     330877   8.4583   NaN        Q
# 6    male  54.0      0      0      17463  51.8625   E46        S

# %%
for name in titanic_df.Name:
    first_name= name.split(",")[-1]
    print(first_name.split(".")[0].strip())
    break
# Out:
# Mr

# %% [markdown]
# Inserting or Replacing a column

# %%
initials = [name.split(",")[-1].split(".")[0].strip() for name in titanic_df.Name]

# %%
titanic_df["initials"] = initials
titanic_df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#   initials
# 0       Mr
# 1      Mrs
# 2     Miss
# 3      Mrs
# 4       Mr

# %%
#Alternative to insert

titanic_df.insert(loc= 3, column="new_initials", value=initials, allow_duplicates= True)

# %%
titanic_df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#   new_initials new_initials     Sex   Age  SibSp  Parch            Ticket  \
# 0           Mr           Mr    male  22.0      1      0         A/5 21171
# 1          Mrs          Mrs  female  38.0      1      0          PC 17599
# 2         Miss         Miss  female  26.0      0      0  STON/O2. 3101282
# 3          Mrs          Mrs  female  35.0      1      0            113803
# 4           Mr           Mr    male  35.0      0      0            373450
#
#       Fare Cabin Embarked initials
# 0   7.2500   NaN        S       Mr
# 1  71.2833   C85        C      Mrs
# 2   7.9250   NaN        S     Miss
# 3  53.1000  C123        S      Mrs
# 4   8.0500   NaN        S       Mr

# %% [markdown]
# Inserting or Replacing Rows

# %%
titanic_df.loc[891,:] = [0, 3, "Braund, Mr. Owen Harris", "Mr", "Mr", "male", 22.0, 1, 0, "A/5 21171", 7.2500, pd.NA, "S", "Mr"]

# %%
titanic_df.tail()
# Out:
#      Survived  Pclass                                      Name new_initials  \
# 887       1.0     1.0              Graham, Miss. Margaret Edith         Miss
# 888       0.0     3.0  Johnston, Miss. Catherine Helen "Carrie"         Miss
# 889       1.0     1.0                     Behr, Mr. Karl Howell           Mr
# 890       0.0     3.0                       Dooley, Mr. Patrick           Mr
# 891       0.0     3.0                   Braund, Mr. Owen Harris           Mr
#
#     new_initials     Sex   Age  SibSp  Parch      Ticket   Fare Cabin  \
# 887         Miss  female  19.0    0.0    0.0      112053  30.00   B42
# 888         Miss  female   NaN    1.0    2.0  W./C. 6607  23.45   NaN
# 889           Mr    male  26.0    0.0    0.0      111369  30.00  C148
# 890           Mr    male  32.0    0.0    0.0      370376   7.75   NaN
# 891           Mr    male  22.0    1.0    0.0   A/5 21171   7.25   NaN
#
#     Embarked initials
# 887        S     Miss
# 888        S     Miss
# 889        C       Mr
# 890        Q       Mr
# 891        S       Mr

# %%
titanic_df.drop(columns="new_initials", inplace=False)
# Out:
#      Survived  Pclass                                               Name  \
# 0         0.0     3.0                            Braund, Mr. Owen Harris
# 1         1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1.0     3.0                             Heikkinen, Miss. Laina
# 3         1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0.0     3.0                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 887       1.0     1.0                       Graham, Miss. Margaret Edith
# 888       0.0     3.0           Johnston, Miss. Catherine Helen "Carrie"
# 889       1.0     1.0                              Behr, Mr. Karl Howell
# 890       0.0     3.0                                Dooley, Mr. Patrick
# 891       0.0     3.0                            Braund, Mr. Owen Harris
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0      male  22.0    1.0    0.0         A/5 21171   7.2500   NaN        S
# 1    female  38.0    1.0    0.0          PC 17599  71.2833   C85        C
# 2    female  26.0    0.0    0.0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0    1.0    0.0            113803  53.1000  C123        S
# 4      male  35.0    0.0    0.0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 887  female  19.0    0.0    0.0            112053  30.0000   B42        S
# 888  female   NaN    1.0    2.0        W./C. 6607  23.4500   NaN        S
# 889    male  26.0    0.0    0.0            111369  30.0000  C148        C
# 890    male  32.0    0.0    0.0            370376   7.7500   NaN        Q
# 891    male  22.0    1.0    0.0         A/5 21171   7.2500   NaN        S
#
#     initials
# 0         Mr
# 1        Mrs
# 2       Miss
# 3        Mrs
# 4         Mr
# ..       ...
# 887     Miss
# 888     Miss
# 889       Mr
# 890       Mr
# 891       Mr
#
# [892 rows x 12 columns]

# %%
titanic_df.shape
# Out:
# (892, 14)

# %% [markdown]
# Handling Null or NaN or NA values

# %%
titanic_df.isna().sum()
# Out:
# Survived          0
# Pclass            0
# Name              0
# new_initials      0
# new_initials      0
# Sex               0
# Age             177
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin           688
# Embarked          2
# initials          0
# dtype: int64

# %% [markdown]
# 1. Removing Null Values
# 2. Fill Something (Imputation)
# 3. Null as new feature (Feature Engineering)
#
# **0 = columnwise - vertical**
# **1 = rowwise - horizontal**

# %%
#Removing Null Values
titanic_df.dropna(subset="Embarked", axis= 0, ignore_index= True, inplace= True)

# %%
titanic_df.shape
# Out:
# (890, 14)

# %%
#Fill Null Values
age_median = print(titanic_df.Age.median())
# Out:
# 28.0

# %%
titanic_df.Age.plot(kind="hist", bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
titanic_df_fillAge = titanic_df.copy()
titanic_df_fillAge = titanic_df.Age.fillna(value= 28, inplace= False)

# %%
titanic_df_fillAge.isna().sum(axis=0)
# Out:
# np.int64(0)

# %%
titanic_df_fillAge
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    19.0
# 886    28.0
# 887    26.0
# 888    32.0
# 889    22.0
# Name: Age, Length: 890, dtype: float64

# %%
titanic_df_fillAge.Age.describe()
# Out:
# count    713.000000
# mean      29.631374
# std       14.485579
# min        0.420000
# 25%       20.000000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
titanic_df_fillAge.Age.plot(kind= "hist",  bins =20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Imputation of Age with respect to Gender
groupby_sex= titanic_df.groupby(by= "Sex")
median_age= groupby_sex["Age"].transform("median")

# %%
median_age
# Out:
# 0      29.0
# 1      27.0
# 2      27.0
# 3      27.0
# 4      29.0
#        ...
# 885    27.0
# 886    27.0
# 887    29.0
# 888    29.0
# 889    29.0
# Name: Age, Length: 890, dtype: float64

# %%
titanic_df.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    19.0
# 886     NaN
# 887    26.0
# 888    32.0
# 889    22.0
# Name: Age, Length: 890, dtype: float64

# %%
titanic_df_fillAge_with_sex = titanic_df.copy()

titanic_df_fillAge_with_sex.loc[:, "Age"] = titanic_df_fillAge_with_sex.Age.fillna(
    value = median_age
)

# %%
titanic_df_fillAge_with_sex.isna().sum()
# Out:
# Survived        0
# Pclass          0
# Name            0
# new_initials    0
# new_initials    0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin           0
# Embarked        0
# initials        0
# dtype: int64

# %%
#Null as a New Feature
titanic_df.Cabin= titanic_df.Cabin.notna().astype(int)

# %%
titanic_df.isna().sum()
# Out:
# Survived          0
# Pclass            0
# Name              0
# new_initials      0
# new_initials      0
# Sex               0
# Age             177
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin             0
# Embarked          0
# initials          0
# dtype: int64

# %%
titanic_df.initials.value_counts()
# Out:
# initials
# Mr              518
# Miss            181
# Mrs             124
# Master           40
# Dr                7
# Rev               6
# Major             2
# Mlle              2
# Col               2
# Don               1
# Mme               1
# Ms                1
# Lady              1
# Sir               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Name: count, dtype: int64

# %%
titanic_df[titanic_df.initials == "Dr"]
# Out:
#      Survived  Pclass                           Name new_initials  \
# 244       0.0     1.0    Minahan, Dr. William Edward           Dr
# 316       0.0     2.0           Moraweck, Dr. Ernest           Dr
# 397       0.0     2.0               Pain, Dr. Alfred           Dr
# 631       1.0     1.0      Stahelin-Maeglin, Dr. Max           Dr
# 659       1.0     1.0  Frauenthal, Dr. Henry William           Dr
# 765       0.0     1.0      Brewe, Dr. Arthur Jackson           Dr
# 795       1.0     1.0    Leader, Dr. Alice (Farnham)           Dr
#
#     new_initials     Sex   Age  SibSp  Parch    Ticket      Fare  Cabin  \
# 244           Dr    male  44.0    2.0    0.0     19928   90.0000      1
# 316           Dr    male  54.0    0.0    0.0     29011   14.0000      0
# 397           Dr    male  23.0    0.0    0.0    244278   10.5000      0
# 631           Dr    male  32.0    0.0    0.0     13214   30.5000      1
# 659           Dr    male  50.0    2.0    0.0  PC 17611  133.6500      0
# 765           Dr    male   NaN    0.0    0.0    112379   39.6000      0
# 795           Dr  female  49.0    0.0    0.0     17465   25.9292      1
#
#     Embarked initials
# 244        Q       Dr
# 316        S       Dr
# 397        S       Dr
# 631        C       Dr
# 659        S       Dr
# 765        C       Dr
# 795        S       Dr

# %% [markdown]
# Handling Null value for Age, using initials groups.

# %%
groupby_initials = titanic_df.groupby(by= "initials")

# %%
median_ages = groupby_initials["Age"].transform("median")

# %%
median_ages
# Out:
# 0      30.0
# 1      35.0
# 2      21.0
# 3      35.0
# 4      30.0
#        ...
# 885    21.0
# 886    21.0
# 887    30.0
# 888    30.0
# 889    30.0
# Name: Age, Length: 890, dtype: float64

# %%
titanic_df_fillAge_with_initial = titanic_df.copy()

titanic_df_fillAge_with_initial.loc[:, "Age"] = titanic_df_fillAge_with_initial.Age.fillna(
    value=median_ages
)

# %%
titanic_df_fillAge_with_initial.Age.plot(kind= "hist" , bins= 20)
# Out:
# <Axes: ylabel='Frequency'>
