# %%
number = 205.8

# %%
type(number)
# Out:
# float

# %%
import math

# %%
math.gcd(25)
# Out:
# 25

# %%
address = str("------              Kathmandu, Nepal           ")

# %%
address.upper()
# Out:
# 'KATHMANDU, NEPAL'

# %%
address.strip("-")
# Out:
# 'Kathmandu, Nepal'

# %%
email = "username234@gmail.com"
email.endswith("skill.com")
# Out:
# False

# %%
address[-4]
# Out:
# 'e'

# %%
address[2: -1: 2]
# Out:
# 'tmnu ea'

# %%
tex= "Hannah"
tex[ : :-1]
# Out:
# 'hannaH'

# %%
sent= f"Your name is {tex.capitalize()} and you live in {address}"
sent
# Out:
# 'Your name is Hannah and you live in Kathmandu, Nepal'

# %%
long_string = """ End of July 2026. """
print(long_string)
# Out:
#  End of July 2026.

# %%
list_example= [1, "Ran", "Smith", 20, 80.9]
print(list_example)
type(list_example)
list_example[-2]
# Out:
# [1, 'Ran', 'Smith', 20, 80.9]
# 20

# %%
fruit= ["apple", "orange"]

# %%
fruit.append("kiwi")

# %%
fruit.insert(1, "papaya")
fruit
# Out:
# ['apple', 'papaya', 'papaya', 'papaya', 'papaya', 'orange', 'kiwi']

# %%
fruit[2] = "watermelon"
fruit
# Out:
# ['apple', 'papaya', 'watermelon', 'papaya', 'papaya', 'orange', 'kiwi']

# %%
fruit.pop(2)
fruit
# Out:
# ['apple', 'papaya', 'orange', 'kiwi']

# %%
mylist= [ 4,9,2,5,8,7,1]
mylist.sort()
mylist
# Out:
# [1, 2, 4, 5, 7, 8, 9]

# %%
sum(mylist)
# Out:
# 36

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "bill no.": [1011,3015,5201]
}
thisdict
# Out:
# {'brand': 'Ford',
#  'model': 'Mustang',
#  'year': 1964,
#  'bill no.': [1011, 3015, 5201]}

# %%
thisdict.get("brand", 0)
# Out:
# 'Ford'

# %%
thisdict["brand"]
# Out:
# 'Ford'

# %%
thisdict["year"] = 2018
thisdict
# Out:
# {'brand': 'Ford',
#  'model': 'Mustang',
#  'year': 2018,
#  'bill no.': [1011, 3015, 5201]}

# %%
thisdict.update({"year": 2019})
thisdict
# Out:
# {'brand': 'Ford',
#  'model': 'Mustang',
#  'year': 2019,
#  'bill no.': [1011, 3015, 5201]}

# %%
thisdict.pop("model")
thisdict
# Out:
# {'brand': 'Ford', 'year': 2019, 'bill no.': [1011, 3015, 5201]}

# %%
thisdict.popitem()
# Out:
# ('bill no.', [1011, 3015, 5201])

# %%
thisdict
# Out:
# {'brand': 'Ford', 'year': 2019}

# %%
thisdict.update({"colour": "Black", "model": "Mustang"})
thisdict
# Out:
# {'brand': 'Ford', 'year': 2019, 'colour': 'Black', 'model': 'Mustang'}

# %%
thisdict.keys()
# Out:
# dict_keys(['brand', 'year', 'colour', 'model'])

# %%
thisdict.items()
# Out:
# dict_items([('brand', 'Ford'), ('year', 2019), ('colour', 'Black'), ('model', 'Mustang')])

# %%
thisdict.values()
# Out:
# dict_values(['Ford', 2019, 'Black', 'Mustang'])

# %%
sorted(thisdict.items())
# Out:
# [('brand', 'Ford'), ('colour', 'Black'), ('model', 'Mustang'), ('year', 2019)]

# %%
dict(sorted(thisdict.items()))
# Out:
# {'brand': 'Ford', 'colour': 'Black', 'model': 'Mustang', 'year': 2019}
