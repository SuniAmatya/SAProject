# %%
set([1,2,3,4])
# Out:
# {1, 2, 3, 4}

# %%
setA= {1,3,6,7,3,2,4,4,9,8}
setA
# Out:
# {1, 2, 3, 4, 6, 7, 8, 9}

# %%
set("missisipi")
# Out:
# {'i', 'm', 'p', 's'}

# %%
setA.add(100)
setA
# Out:
# {1, 2, 3, 4, 6, 7, 8, 9, 100}

# %%
setA.update([99, 33, 44], "trial", ["trial"])
setA
# Out:
# {1, 100, 2, 3, 33, 4, 44, 6, 7, 8, 9, 99, 'a', 'i', 'l', 'r', 't', 'trial'}

# %%
setA.discard(100)
setA
# Out:
# {1, 2, 3, 33, 4, 44, 6, 7, 8, 9, 99, 'a', 'i', 'l', 'r', 't', 'trial'}

# %%
setA.remove(99)
setA
# Out:
# {1, 2, 3, 33, 4, 44, 6, 7, 8, 9, 'a', 'i', 'l', 'r', 't', 'trial'}

# %%
setA.pop()
# Out:
# 1

# %%
a = {1,3,2,4,6,9}
b = {1,4,7,3,8,9}
c = {1,3,9}
d= {0,5}
aUb= a.union(b)
aUb
# Out:
# {1, 2, 3, 4, 6, 7, 8, 9}

# %%
a|b
# Out:
# {1, 2, 3, 4, 6, 7, 8, 9}

# %%
b_a= b.difference(a) #b-a
b_a
# Out:
# {7, 8}

# %%
aVb= a.intersection(b)
aVb
# Out:
# {1, 3, 4, 9}

# %%
a.symmetric_difference(b)
# Out:
# {2, 6, 7, 8}

# %%
c.issubset(a) #c<=a
# Out:
# True

# %%
c<a #Proper subset
# Out:
# True

# %%
a.issuperset(c) #a>=c
# Out:
# True

# %%
a>c #proper superset
# Out:
# True

# %%
d.isdisjoint(a)
# Out:
# True

# %%
b. isdisjoint(c)
# Out:
# False
